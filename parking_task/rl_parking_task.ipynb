# %%
# !pip install gymnasium
# !pip install git+https://github.com/DLR-RM/stable-baselines3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gymnasium
#   Downloading gymnasium-1.2.3-py3-none-any.whl (952 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.1/952.1 KB 4.7 MB/s eta 0:00:0000:0100:01
# Collecting cloudpickle>=1.2.0
#   Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/lib/python3/dist-packages (from gymnasium) (1.21.5)
# Collecting farama-notifications>=0.0.1
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Collecting typing-extensions>=4.3.0
#   Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Installing collected packages: farama-notifications, typing-extensions, cloudpickle, gymnasium
# Successfully installed cloudpickle-3.1.2 farama-notifications-0.0.4 gymnasium-1.2.3 typing-extensions-4.15.0
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/DLR-RM/stable-baselines3
#   Cloning https://github.com/DLR-RM/stable-baselines3 to /tmp/pip-req-build-gprszehl
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/stable-baselines3 /tmp/pip-req-build-gprszehl
#   Resolved https://github.com/DLR-RM/stable-baselines3 to commit cc20f5af0cfec798d8c8d26bc9886b1a38ead90c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib in /usr/lib/python3/dist-packages (from stable-baselines3==2.8.0a4) (3.5.1)
# Requirement already satisfied: pandas in /usr/lib/python3/dist-packages (from stable-baselines3==2.8.0a4) (1.3.5)
# Requirement already satisfied: cloudpickle in /home/GTL/fsangare/.local/lib/python3.10/site-packages (from stable-baselines3==2.8.0a4) (3.1.2)
# Collecting torch<3.0,>=2.3
#   Downloading torch-2.10.0-3-cp310-cp310-manylinux_2_28_x86_64.whl (915.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.5/915.5 MB 911.4 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in /home/GTL/fsangare/.local/lib/python3.10/site-packages (from stable-baselines3==2.8.0a4) (1.2.3)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/lib/python3/dist-packages (from stable-baselines3==2.8.0a4) (1.21.5)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/GTL/fsangare/.local/lib/python3.10/site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3==2.8.0a4) (0.0.4)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/GTL/fsangare/.local/lib/python3.10/site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3==2.8.0a4) (4.15.0)
# Collecting sympy>=1.13.3
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 17.7 MB/s eta 0:00:0000:0100:01
# Collecting fsspec>=0.8.5
#   Downloading fsspec-2026.2.0-py3-none-any.whl (202 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.5/202.5 KB 4.7 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-cublas-cu12==12.8.4.1
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 1.2 MB/s eta 0:00:0000:0100:01
# Collecting triton==3.6.0
#   Downloading triton-3.6.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (188.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.1/188.1 MB 3.8 MB/s eta 0:00:0000:0100:01
# Collecting networkx>=2.5.1
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 13.8 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-cupti-cu12==12.8.90
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 19.5 MB/s eta 0:00:0000:010:01
# Collecting nvidia-cusolver-cu12==11.7.3.90
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 2.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch<3.0,>=2.3->stable-baselines3==2.8.0a4) (3.0.3)
# Collecting nvidia-nvshmem-cu12==3.4.5
#   Downloading nvidia_nvshmem_cu12-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (139.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.1/139.1 MB 4.7 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvjitlink-cu12==12.8.93
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 10.8 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 6.8 MB/s eta 0:00:00:00:0100:01
# Collecting nvidia-cufft-cu12==11.3.3.83
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 3.4 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvtx-cu12==12.8.90
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 KB 1.7 MB/s eta 0:00:00ta 0:00:01
# Collecting nvidia-cudnn-cu12==9.10.2.21
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 1.1 MB/s eta 0:00:0000:0100:01
# Collecting cuda-bindings==12.9.4
#   Downloading cuda_bindings-12.9.4-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 23.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from torch<3.0,>=2.3->stable-baselines3==2.8.0a4) (3.6.0)
# Collecting nvidia-cufile-cu12==1.13.1.3
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.6 MB/s eta 0:00:0000:01
# Collecting nvidia-cusparse-cu12==12.5.8.93
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 2.6 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-curand-cu12==10.3.9.90
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 9.4 MB/s eta 0:00:00:00:0100:01
# Collecting nvidia-nccl-cu12==2.27.5
#   Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 2.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-runtime-cu12==12.8.90
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 KB 10.9 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparselt-cu12==0.7.1
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 2.6 MB/s eta 0:00:0000:0100:01
# Collecting cuda-pathfinder~=1.1
#   Downloading cuda_pathfinder-1.4.2-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 KB 3.2 MB/s eta 0:00:00
# Collecting mpmath<1.4,>=1.1.0
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Building wheels for collected packages: stable-baselines3
#   Building wheel for stable-baselines3 (pyproject.toml) ... done
#   Created wheel for stable-baselines3: filename=stable_baselines3-2.8.0a4-py3-none-any.whl size=187380 sha256=4b66a155045619ee030d809869b48bd272fdb9528dbae828064a2a439edac9c0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zq8eh_so/wheels/3b/24/65/bc2794face336930a72bdbe36faf5aad6e2352b3d1dec310ca
# Successfully built stable-baselines3
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, triton, sympy, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, fsspec, cuda-pathfinder, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, cuda-bindings, nvidia-cusolver-cu12, torch, stable-baselines3
# Successfully installed cuda-bindings-12.9.4 cuda-pathfinder-1.4.2 fsspec-2026.2.0 mpmath-1.3.0 networkx-3.4.2 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvshmem-cu12-3.4.5 nvidia-nvtx-cu12-12.8.90 stable-baselines3-2.8.0a4 sympy-1.14.0 torch-2.10.0 triton-3.6.0

# %%
# !pip install numpy>=1.24.0

# %%
np.__version__
# Out:
# '1.21.5'

# %%
import numpy as np
import gymnasium as gym
from typing import Optional
import matplotlib.pyplot as plt

# %%
def wrap_angle_to_pi(angle):
    return np.arctan2(np.sin(angle), np.cos(angle))


class Controller:
  def __init__(self, k_rho=15, k_alpha=5, k_beta=-2) -> None:
    self.k_rho = k_rho
    self.k_alpha = k_alpha
    self.k_beta = k_beta

  def get_cmds(self, rho, alpha, beta):
    """
      This function applies the control low v = k*rho and w = k*alpha + k*beta
      given angle errors

      input:
      - rho: distance to target pos
        - bearing angle alpha between robot and target pos
        - beta: goal heading in world frame

      output:
      - v: linear speed of the robot
      - omega: angular speed of the unicycle robot
    """
    v = self.k_rho*rho
    omega = self.k_beta*beta + self.k_alpha*alpha

    return v, omega

class Robot:
  def __init__(self, L=1, max_speed=(2.0, 1.0)) -> None:

    self.config = np.array([0., 0., 0.])
    self.speed = np.array([0.0, 0.0, 0.0])

    self.L = L # length of the robot car
    self.delta_t = 0.02 # second
    self.max_speed = max_speed

  def update_bicycle(self, v, gamma):
    """
      This function implements the bicycle model kinematics.
      Given inputs commands v and gamma, it computes the new
      configuration of the robot from the current configuration
      using the euler integration

      x = x + x_dot*delta_t
      y = y + y_dot*delta_t
      theta = theta + theta_dot*delta_t

      input:
        - speed v
        - steering angle gamma

      action:
        - update configuration at time step t+1
    """
    x_dot = v*np.cos(self.config[2]) # v*cos(theta)
    y_dot = v*np.sin(self.config[2]) # v*sin(theta)
    theta_dot = (v/self.L)*np.tan(gamma) # v*tan(gamma)/L
    theta_dot = np.clip(theta_dot, -self.max_speed[1], self.max_speed[1])

    self.speed[0] = x_dot.copy()
    self.speed[1] = y_dot.copy()

    self.speed[2] = theta_dot

    self.config[0] = self.config[0] + x_dot*self.delta_t
    self.config[1] = self.config[1] + y_dot*self.delta_t
    self.config[2] = self.config[2] + theta_dot*self.delta_t

    self.config[2] = wrap_angle_to_pi(self.config[2])

    return


  def uni2bicycle(self, v, omega):
    """
      This function transform commands inputs (v, omega) for unicycle robot to
      bicycle robot (v, gamma)

      input:
        - v: linear speed
        - omega: angular speed

      output:
        - v: same linear speed
        - gamma: steering angle of the front wheel
    """
    val = omega*self.L/(v+1e-6)
    gamma = np.arctan2(np.sin(val), np.cos(val))

    return v, gamma

  def cartesian2polar(self, delta_x, delta_y):
    """
      This function takes as input delta_x and delta_x and
      compute the polar coordinates rho, alpha, beta for the
      control

      input:
        - delta_x: x coordinate
        - delta_y: y coordinate

      output:
        - alpha: angle of delta_x and delta_y in robot frame
        - rho: norm of the vector (delta_x, delta_y)
        - beta: angle of goal in world frame
    """
    rho = np.linalg.norm(np.array([delta_x, delta_y]))
    alpha = np.arctan2(delta_y, delta_x) - self.config[2]
    alpha = wrap_angle_to_pi(alpha)

    beta = -(alpha + self.config[2])
    beta = wrap_angle_to_pi(beta)


    return rho, alpha, beta

  def update_kinematics(self, v, omega):
    """
      This function implements one step update of the kinematic model
    """


    #print(f"config: {v, omega}")
    # 5. transform to bicycle model commands v and gamma
    v, gamma = self.uni2bicycle(v, omega)

    # 6. update robot kinematic using bicycle model
    self.update_bicycle(v, gamma)

# %%
class ParkingTask(gym.Env):
  def __init__(self, config=None) -> None:

    self.action_space = gym.spaces.Box(low=-1, high=1, shape=(2, ))
    self.observation_space = gym.spaces.Box(low=-1, high=1, shape=(8, ))
    self.robot = Robot()

    self.target_config = np.array([0., 0., 0.])
    self.start_config = np.array([0., 0., 0.])

    self.prev_distance_to_target = 0
    self.distance_to_target = 0
    self.bearing = 0
    self.target_bearing = 0
    self.initial_distance_to_target = 0


    self.grid_size = (5, 5)
    self.weights = {"dist": 20., "bearing": -4., "orient":1.5}

    self.time = 0
    self.max_time_step = 20
    self.step_dt = 0.02
    self.robot.delta_t = self.step_dt

    self.reward_dist = 0
    self.reward_bearing = 0
    self.reward_orient = 0
    self.reward_goal = 0
    self.reward_time = 0
    self.reward_target_bearing = 0
    
  def _get_info(self):

    return {}

  def _get_obs(self):

    dx = self.target_config[0] - self.robot.config[0]
    dy = self.target_config[1] - self.robot.config[1]

    self.bearing = np.arctan2(dy, dx) - self.robot.config[2]
    self.bearing = (self.bearing + np.pi) % (2*np.pi) - np.pi
    self.bearing = wrap_angle_to_pi(self.bearing)

    
    self.target_bearing = np.arctan2(dy, dx) - self.target_config[2]
    self.target_bearing = wrap_angle_to_pi(self.target_bearing)

    self.distance_to_target = np.sqrt(dx**2 + dy**2)

    normalized_lin_speed = self.robot.speed[:2]/self.robot.max_speed[0]
    normalized_ang_speed = self.robot.speed[2]/self.robot.max_speed[1]
    normalized_distance = np.clip(self.distance_to_target/self.initial_distance_to_target, -1, 1)

    obs = np.array([
        np.sin(self.target_bearing).item(), # 1
        np.cos(self.target_bearing).item(), # 1
        np.sin(self.bearing).item(), # 1
        np.cos(self.bearing).item(), # 1
        normalized_distance.item(), # 1
        normalized_ang_speed.item(), # 1
        normalized_lin_speed[0].item(), # 1
        normalized_lin_speed[1].item() # 1
      
    ])
    
    return obs

  def reset(self, seed: Optional[int] = None, options: Optional[dict] = None):

    # IMPORTANT: Must call this first to seed the random number generator
    super().reset(seed=seed)

    low, high = -self.grid_size[0], self.grid_size[0]
    self.target_config[:2] = np.random.uniform(low=low, high=high, size=(2, ))
    self.start_config[:2] = np.random.uniform(low=low, high=high, size=(2, ))

    self.target_config[2] = np.random.uniform(-np.pi, np.pi)
    self.start_config[2] = np.random.uniform(-np.pi, np.pi)

    self.robot.config = self.start_config.copy()

    self.initial_distance_to_target = np.linalg.norm(self.target_config[:2]-self.start_config[:2])
    self.prev_distance_to_target = self.initial_distance_to_target

    self.time = 0

    obs = self._get_obs()
    info = self._get_info()

    return obs, info

  def _get_reward(self):

    #rew_dist = 0.03*self.weights["dist"]*self.robot.distance_to_target
    distance_progr = (1/self.step_dt)*(self.prev_distance_to_target - self.distance_to_target)/(self.robot.max_speed[0])
    rew_distance = 5*distance_progr
    
    self.reward_dist = rew_distance
    condition = self.distance_to_target<=1.5

    rew_bearing = np.exp(self.weights["bearing"] * np.abs(self.bearing)) - 1 if not condition else 0.0
    rew_target_bearing = np.exp(self.weights["bearing"]*np.abs(self.target_bearing)) - 1 if condition else 0.0
    

    self.reward_target_bearing = rew_target_bearing
    self.reward_bearing = rew_bearing
    #reward_goal = 100 if self.robot.distance_to_target<=0.02 else 0
    rew_time = -0.5
    self.reward_time = rew_time
    
    rew_goal = 100 if np.abs(self.target_bearing)<=0.15 else 0 #np.abs(self.distance_to_target)<=0.02 and
    self.reward_goal = rew_goal

    outbound = abs(self.robot.config[0]) > self.grid_size[0] or abs(self.robot.config[1]) > self.grid_size[1]
    rew_outbound = -1000 if outbound else 0

    rewards_total =  rew_time + rew_goal + rew_bearing + rew_distance + rew_target_bearing #+ time_rew + rew_bearing #+ time_rew #+ rew_outbound + time_rew

    return rewards_total

  def step(self, action):

    v, omega = action
    
    v = v*self.robot.max_speed[0]
    omega = omega*self.robot.max_speed[1]
    
    v = np.clip(v, -self.robot.max_speed[0], self.robot.max_speed[0])
    omega = np.clip(omega, -self.robot.max_speed[1], self.robot.max_speed[1])

    self.robot.update_kinematics(v, omega)
    #print(f"pos: {self.robot.config}")

    self.time += self.step_dt

    outbound = abs(self.robot.config[0]) > self.grid_size[0] or abs(self.robot.config[1]) > self.grid_size[1]
    timeout = self.time > self.max_time_step

    terminated = self.distance_to_target<=0.05 and np.abs(self.target_bearing)<=0.15 #
    
    #print(f"terminated: {terminated} bear: {self.robot.bearing}")
    truncated = timeout #| outbound
    self.timeout = (timeout, outbound)
    obs = self._get_obs()
    info = self._get_info()
    reward = self._get_reward()

    self.prev_distance_to_target = float(self.distance_to_target)

    return obs, reward, terminated, truncated, info

# Register the environment so we can create it with gym.make()
gym.register(
    id="gymnasium_env/ParkingTask-v0",
    entry_point=ParkingTask,
    #max_episode_steps=800,  # Prevent infinite episodes
)
# Out:
# /mnt/ssd-storage/fsangare/isaaclab/lib/python3.10/site-packages/gymnasium/envs/registration.py:648: UserWarning: WARN: Overriding environment gymnasium_env/ParkingTask-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
robot = Robot()
np.random.seed(np.random.randint(10))
envs = gym.make("gymnasium_env/ParkingTask-v0")
envs = gym.wrappers.RecordEpisodeStatistics(envs)
envs.unwrapped.robot.max_speed = (2., 1.0)
obs, info = envs.reset()


done = False
pos_traj = [envs.unwrapped.start_config[:2].copy()]
orientation_traj = [envs.unwrapped.start_config[2]]
bearing_traj = [envs.unwrapped.bearing.copy()]

rewards_episode = []
rewards_dist = []
rewards_bearing = []  
rewards_target_bearing = [] 
rewards_orient = []
rewards_goal = []

total_reward = 0
rewards_evolution = []

controller = Controller(k_rho=0.5, k_alpha=3, k_beta=-1.5)


while not done:

  dx = envs.unwrapped.target_config[0] - envs.unwrapped.robot.config[0]
  dy = envs.unwrapped.target_config[1] - envs.unwrapped.robot.config[1]

  rho, alpha, beta = envs.unwrapped.robot.cartesian2polar(dx, dy)

  # Add target angle to beta otherwise the final orientation will be missed
  beta = beta + envs.unwrapped.target_config[2]
  beta = wrap_angle_to_pi(beta)
  
  v, omega = controller.get_cmds(rho, alpha, beta)

  action = (v, omega)
  next_obs, rew, terminated, truncated, info = envs.step(action)
  total_reward += rew
  pos_traj.append(envs.unwrapped.robot.config[:2].copy())
  orientation_traj.append(envs.unwrapped.robot.config[2].copy())
  bearing_traj.append(envs.unwrapped.bearing.copy())
  
  done = terminated or truncated
  rewards_episode.append(rew)
  rewards_evolution.append(total_reward)
  rewards_dist.append(envs.unwrapped.reward_dist)
  rewards_bearing.append(envs.unwrapped.reward_bearing)
  rewards_orient.append(envs.unwrapped.reward_orient)
  rewards_goal.append(envs.unwrapped.reward_goal)
  rewards_target_bearing.append(envs.unwrapped.reward_target_bearing)

  obs = next_obs.copy()

print(f"truncate: {truncated} terminate: {terminated} outbound: {envs.unwrapped.timeout} pos: {envs.unwrapped.robot.config}")
print(f"distance to target: {envs.unwrapped.distance_to_target}")
print(f"final time: {envs.unwrapped.time}")
print(f"episode_returns: {envs.episode_returns}")
print(f"episode_length: {envs.episode_lengths}")
import matplotlib.pyplot as plt

def plot_traj():


    plt.figure()
    x, y = zip(*pos_traj)
    plt.plot(x, y, label="pos")
    plt.scatter(envs.unwrapped.target_config[0], envs.unwrapped.target_config[1], c="r", label="goal")
    plt.scatter(envs.unwrapped.start_config[0], envs.unwrapped.start_config[1], c="g", label="start")
    plt.scatter(envs.unwrapped.robot.config[0], envs.unwrapped.robot.config[1], c="b", label="final")

    dx_target, dy_target = np.cos(envs.unwrapped.target_config[2]), np.sin(envs.unwrapped.target_config[2])
    dx_start, dy_start = np.cos(envs.unwrapped.start_config[2]), np.sin(envs.unwrapped.start_config[2])
    dx_final, dy_final = np.cos(envs.unwrapped.robot.config[2]), np.sin(envs.unwrapped.robot.config[2])
    length = 1.5
    width = 0.3

    plt.arrow(x=envs.unwrapped.target_config[0], y=envs.unwrapped.target_config[1],
              dx=length*dx_target, dy=length*dy_target, color="r", head_width=0.3)
    plt.arrow(x=envs.unwrapped.start_config[0], y=envs.unwrapped.start_config[1],
              dx=length*dx_start, dy=length*dy_start, color="g", head_width=0.3)
    plt.arrow(x=envs.unwrapped.robot.config[0], y=envs.unwrapped.robot.config[1],
              dx=0.6*length*dx_final, dy=0.6*length*dy_final, color="b", head_width=0.1)

    plt.legend()
    plt.axis("equal")

    plt.figure()
    plt.plot(orientation_traj, label="head")
    plt.hlines(envs.unwrapped.target_config[2:], xmin=0, xmax=len(orientation_traj), colors=["r"], label="target")
    plt.hlines(envs.unwrapped.start_config[2:], xmin=0, xmax=len(orientation_traj), colors=["g"], label="start")
    plt.legend()

plot_traj()

plt.figure()
plt.plot(rewards_episode, label="reward")
plt.legend()

plt.figure()
plt.plot(rewards_evolution, label="reward evolution")
plt.legend()

plt.figure()
plt.plot(bearing_traj, label="bearing")
plt.legend()

plt.figure()
plt.plot(bearing_traj[1:], rewards_episode, label="bearing vs reward")
plt.legend()

plt.figure()
plt.plot(rewards_dist, label="reward dist")
plt.legend()

plt.figure()
plt.plot(rewards_bearing, label="reward bearing", c="r")
plt.plot(rewards_target_bearing, label="reward target bearing", c="b")
plt.legend()  

plt.figure()
plt.plot(rewards_goal, label="reward goal")
plt.legend()
# Out:
# /mnt/ssd-storage/fsangare/isaaclab/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:134: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# /mnt/ssd-storage/fsangare/isaaclab/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:158: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# /mnt/ssd-storage/fsangare/isaaclab/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:134: UserWarning: WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# /mnt/ssd-storage/fsangare/isaaclab/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:158: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# truncate: False terminate: True outbound: (False, False) pos: [-4.1891488   2.79409728  3.06596966]
# distance to target: 0.04803879160576063
# final time: 8.279999999999912
# episode_returns: -154.7412157140684
# episode_length: 414

# %%
#
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import (EvalCallback, CheckpointCallback, 
CallbackList, BaseCallback)

# %%
vec_env = make_vec_env("gymnasium_env/ParkingTask-v0", n_envs=256)

eval_env = gym.make("gymnasium_env/ParkingTask-v0")
model = PPO("MlpPolicy", vec_env, verbose=1, n_steps=2048, batch_size=65536,
            tensorboard_log="./ppo_parkingtask_tensorboard/", ent_coef=0.001, n_epochs=10)


class ParkingMetricsCallback(BaseCallback):
    def __init__(self, verbose=0):
        super().__init__(verbose)

    def _on_step(self):
        # Access all underlying envs in the VecEnv
        envs = self.training_env.envs

        # Collect reward components from each env
        dist_rewards = []
        goal_rewards = []
        bearing_rewards = []
        time_rewards = []
        target_bearing_rewards = []

        for env in envs:
            env = env.unwrapped
            dist_rewards.append(env.reward_dist)
            goal_rewards.append(env.reward_goal)
            bearing_rewards.append(env.reward_bearing)
            target_bearing_rewards.append(env.reward_target_bearing)
            time_rewards.append(env.reward_time if hasattr(env, "reward_time") else 0.0)

        # Compute means
        mean_dist = np.mean(dist_rewards)
        mean_goal = np.mean(goal_rewards)
        mean_bearing = np.mean(bearing_rewards)
        mean_time = np.mean(time_rewards)

        # Log to TensorBoard
        self.logger.record("parking/reward_dist_mean", mean_dist)
        self.logger.record("parking/reward_goal_mean", mean_goal)
        self.logger.record("parking/reward_bearing_mean", mean_bearing)
        self.logger.record("parking/reward_time_mean", mean_time)

        return True



callback = CallbackList([
    CheckpointCallback(save_freq=30000, save_path="./checkpoints/"),
    EvalCallback(eval_env, best_model_save_path="./best_model/", eval_freq=30000),
    ParkingMetricsCallback()
])

model.learn(total_timesteps=100_000_000, callback=callback, tb_log_name="first_run")
# Out:
# Using cuda device
# Logging to ./ppo_parkingtask_tensorboard/first_run_15
# /mnt/ssd-storage/fsangare/isaaclab/lib/python3.10/site-packages/gymnasium/envs/registration.py:740: UserWarning: WARN: The environment is being initialised with render_mode='rgb_array' that is not in the possible render_modes ([]).
#   logger.warn(
# /mnt/ssd-storage/fsangare/isaaclab/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# --------------------------------------
# | parking/               |           |
# |    reward_bearing_mean | -0.938    |
# |    reward_dist_mean    | 0.0744    |
# |    reward_goal_mean    | 0         |
# |    reward_time_mean    | -0.5      |
# | rollout/               |           |
# |    ep_len_mean         | 1e+03     |
# |    ep_rew_mean         | -1.46e+03 |
# | time/                  |           |
# |    fps                 | 11438     |
# |    iterations          | 1         |
# |    time_elapsed        | 45        |
# |    total_timesteps     | 524288    |
# --------------------------------------
# -----------------------------------------
# | parking/                |             |
# |    reward_bearing_mean  | -0.932      |
# |    reward_dist_mean     | 0.384       |
# |    reward_goal_mean     | 0           |
# |    reward_time_mean     | -0.5        |
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -1.35e+03   |
# | time/                   |             |
# |    fps                  | 11203       |
# |    iterations           | 2           |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 1048576     |
# | train/                  |             |
# |    approx_kl            | 0.010398208 |
# |    clip_fraction        | 0.0574      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0.00105     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 284         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0182     |
# |    std                  | 0.988       |
# |    value_loss           | 610         |
# -----------------------------------------
# -----------------------------------------
# | parking/                |             |
# |    reward_bearing_mean  | -0.933      |
# |    reward_dist_mean     | 0.536       |
# |    reward_goal_mean     | 0           |
# |    reward_time_mean     | -0.5        |
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -1.45e+03   |
# | time/                   |             |
# |    fps                  | 11249       |
# |    iterations           | 3           |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 1572864     |
# | train/                  |             |
# |    approx_kl            | 0.006791353 |
# |    clip_fraction        | 0.0348      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | -0.012      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 258         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00977    |
# |    std                  | 0.977       |
# |    value_loss           | 574         |
# -----------------------------------------
# -----------------------------------------
# | parking/                |             |
# |    reward_bearing_mean  | -0.956      |
# |    reward_dist_mean     | 0.411       |
# |    reward_goal_mean     | 0           |
# |    reward_time_mean     | -0.5        |
# | rollout/                |             |
# |    ep_len_mean          | 991         |
# |    ep_rew_mean          | -1.45e+03   |
# | time/                   |             |
# |    fps                  | 11178       |
# |    iterations           | 4           |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 2097152     |
# | train/                  |             |
# |    approx_kl            | 0.003281078 |
# |    clip_fraction        | 0.0108      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | -0.043      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 254         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00441    |
# |    std                  | 0.968       |
# |    value_loss           | 574         |
# -----------------------------------------
# -----------------------------------------
# | parking/                |             |
# |    reward_bearing_mean  | -0.978      |
# |    reward_dist_mean     | 0.327       |
# |    reward_goal_mean     | 0           |
# |    reward_time_mean     | -0.5        |
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -1.44e+03   |
# | time/                   |             |
# |    fps                  | 11131       |
# |    iterations           | 5           |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 2621440     |
# | train/                  |             |
# |    approx_kl            | 0.002326779 |
# |    clip_fraction        | 0.00614     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | -0.0711     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 261         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0028     |
# |    std                  | 0.965       |
# |    value_loss           | 584         |
# -----------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.983       |
# |    reward_dist_mean     | 0.396        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -1.49e+03    |
# | time/                   |              |
# |    fps                  | 11096        |
# |    iterations           | 6            |
# |    time_elapsed         | 283          |
# |    total_timesteps      | 3145728      |
# | train/                  |              |
# |    approx_kl            | 0.0019535716 |
# |    clip_fraction        | 0.00444      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | -0.067       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 273          |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00215     |
# |    std                  | 0.961        |
# |    value_loss           | 599          |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.994       |
# |    reward_dist_mean     | 0.26         |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 991          |
# |    ep_rew_mean          | -1.39e+03    |
# | time/                   |              |
# |    fps                  | 11063        |
# |    iterations           | 7            |
# |    time_elapsed         | 331          |
# |    total_timesteps      | 3670016      |
# | train/                  |              |
# |    approx_kl            | 0.0018013946 |
# |    clip_fraction        | 0.003        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | -0.0485      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 274          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00147     |
# |    std                  | 0.956        |
# |    value_loss           | 594          |
# ------------------------------------------
# -----------------------------------------
# | parking/                |             |
# |    reward_bearing_mean  | -0.994      |
# |    reward_dist_mean     | 0.107       |
# |    reward_goal_mean     | 0           |
# |    reward_time_mean     | -0.5        |
# | rollout/                |             |
# |    ep_len_mean          | 994         |
# |    ep_rew_mean          | -1.44e+03   |
# | time/                   |             |
# |    fps                  | 11047       |
# |    iterations           | 8           |
# |    time_elapsed         | 379         |
# |    total_timesteps      | 4194304     |
# | train/                  |             |
# |    approx_kl            | 0.001872956 |
# |    clip_fraction        | 0.0032      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | -0.0439     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 279         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00124    |
# |    std                  | 0.951       |
# |    value_loss           | 600         |
# -----------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.994       |
# |    reward_dist_mean     | 0.165        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 985          |
# |    ep_rew_mean          | -1.35e+03    |
# | time/                   |              |
# |    fps                  | 11039        |
# |    iterations           | 9            |
# |    time_elapsed         | 427          |
# |    total_timesteps      | 4718592      |
# | train/                  |              |
# |    approx_kl            | 0.0021164622 |
# |    clip_fraction        | 0.00354      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.73        |
# |    explained_variance   | -0.0353      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 287          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00113     |
# |    std                  | 0.946        |
# |    value_loss           | 615          |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.993       |
# |    reward_dist_mean     | 0.172        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -1.43e+03    |
# | time/                   |              |
# |    fps                  | 11022        |
# |    iterations           | 10           |
# |    time_elapsed         | 475          |
# |    total_timesteps      | 5242880      |
# | train/                  |              |
# |    approx_kl            | 0.0021394312 |
# |    clip_fraction        | 0.00388      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.72        |
# |    explained_variance   | -0.0293      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 290          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00119     |
# |    std                  | 0.94         |
# |    value_loss           | 615          |
# ------------------------------------------
# -----------------------------------------
# | parking/                |             |
# |    reward_bearing_mean  | -0.996      |
# |    reward_dist_mean     | 0.315       |
# |    reward_goal_mean     | 0           |
# |    reward_time_mean     | -0.5        |
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -1.29e+03   |
# | time/                   |             |
# |    fps                  | 11013       |
# |    iterations           | 11          |
# |    time_elapsed         | 523         |
# |    total_timesteps      | 5767168     |
# | train/                  |             |
# |    approx_kl            | 0.003329568 |
# |    clip_fraction        | 0.00664     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | -0.0218     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 283         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00118    |
# |    std                  | 0.933       |
# |    value_loss           | 603         |
# -----------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.994       |
# |    reward_dist_mean     | 0.265        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 995          |
# |    ep_rew_mean          | -1.25e+03    |
# | time/                   |              |
# |    fps                  | 11007        |
# |    iterations           | 12           |
# |    time_elapsed         | 571          |
# |    total_timesteps      | 6291456      |
# | train/                  |              |
# |    approx_kl            | 0.0031854631 |
# |    clip_fraction        | 0.00748      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.68        |
# |    explained_variance   | -0.0166      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 262          |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00127     |
# |    std                  | 0.923        |
# |    value_loss           | 553          |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.994       |
# |    reward_dist_mean     | 0.224        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 993          |
# |    ep_rew_mean          | -1.36e+03    |
# | time/                   |              |
# |    fps                  | 10999        |
# |    iterations           | 13           |
# |    time_elapsed         | 619          |
# |    total_timesteps      | 6815744      |
# | train/                  |              |
# |    approx_kl            | 0.0035104463 |
# |    clip_fraction        | 0.00793      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.67        |
# |    explained_variance   | -0.0135      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 273          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00115     |
# |    std                  | 0.917        |
# |    value_loss           | 570          |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.995       |
# |    reward_dist_mean     | 0.339        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 984          |
# |    ep_rew_mean          | -1.33e+03    |
# | time/                   |              |
# |    fps                  | 10991        |
# |    iterations           | 14           |
# |    time_elapsed         | 667          |
# |    total_timesteps      | 7340032      |
# | train/                  |              |
# |    approx_kl            | 0.0034393813 |
# |    clip_fraction        | 0.00701      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.65        |
# |    explained_variance   | -0.00963     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 295          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000934    |
# |    std                  | 0.909        |
# |    value_loss           | 621          |
# ------------------------------------------
# /mnt/ssd-storage/fsangare/isaaclab/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=7680000, episode_reward=-1850.94 +/- 296.35
# Episode length: 1001.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | -1.85e+03    |
# | parking/                |              |
# |    reward_bearing_mean  | -0.997       |
# |    reward_dist_mean     | 0.111        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | time/                   |              |
# |    total_timesteps      | 7680000      |
# | train/                  |              |
# |    approx_kl            | 0.0034665356 |
# |    clip_fraction        | 0.00749      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.63        |
# |    explained_variance   | -0.00727     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 311          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00108     |
# |    std                  | 0.902        |
# |    value_loss           | 647          |
# ------------------------------------------
# New best mean reward!
# --------------------------------------
# | parking/               |           |
# |    reward_bearing_mean | -0.994    |
# |    reward_dist_mean    | 0.194     |
# |    reward_goal_mean    | 0         |
# |    reward_time_mean    | -0.5      |
# | rollout/               |           |
# |    ep_len_mean         | 972       |
# |    ep_rew_mean         | -1.35e+03 |
# | time/                  |           |
# |    fps                 | 10912     |
# |    iterations          | 15        |
# |    time_elapsed        | 720       |
# |    total_timesteps     | 7864320   |
# --------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.997       |
# |    reward_dist_mean     | 0.197        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 995          |
# |    ep_rew_mean          | -1.44e+03    |
# | time/                   |              |
# |    fps                  | 10909        |
# |    iterations           | 16           |
# |    time_elapsed         | 768          |
# |    total_timesteps      | 8388608      |
# | train/                  |              |
# |    approx_kl            | 0.0032883263 |
# |    clip_fraction        | 0.00696      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.62        |
# |    explained_variance   | -0.00571     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 321          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000847    |
# |    std                  | 0.895        |
# |    value_loss           | 668          |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.997       |
# |    reward_dist_mean     | 0.0936       |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 964          |
# |    ep_rew_mean          | -1.44e+03    |
# | time/                   |              |
# |    fps                  | 10904        |
# |    iterations           | 17           |
# |    time_elapsed         | 817          |
# |    total_timesteps      | 8912896      |
# | train/                  |              |
# |    approx_kl            | 0.0031367114 |
# |    clip_fraction        | 0.00474      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.6         |
# |    explained_variance   | -0.00506     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 363          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000616    |
# |    std                  | 0.891        |
# |    value_loss           | 750          |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.997       |
# |    reward_dist_mean     | 0.122        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 986          |
# |    ep_rew_mean          | -1.55e+03    |
# | time/                   |              |
# |    fps                  | 10896        |
# |    iterations           | 18           |
# |    time_elapsed         | 866          |
# |    total_timesteps      | 9437184      |
# | train/                  |              |
# |    approx_kl            | 0.0022811498 |
# |    clip_fraction        | 0.00211      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.59        |
# |    explained_variance   | -0.00378     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 402          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000548    |
# |    std                  | 0.884        |
# |    value_loss           | 833          |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.997       |
# |    reward_dist_mean     | 0.109        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 993          |
# |    ep_rew_mean          | -1.52e+03    |
# | time/                   |              |
# |    fps                  | 10888        |
# |    iterations           | 19           |
# |    time_elapsed         | 914          |
# |    total_timesteps      | 9961472      |
# | train/                  |              |
# |    approx_kl            | 0.0026090452 |
# |    clip_fraction        | 0.00209      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.58        |
# |    explained_variance   | -0.00317     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 423          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000538    |
# |    std                  | 0.879        |
# |    value_loss           | 878          |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.992       |
# |    reward_dist_mean     | 0.246        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 963          |
# |    ep_rew_mean          | -1.52e+03    |
# | time/                   |              |
# |    fps                  | 10880        |
# |    iterations           | 20           |
# |    time_elapsed         | 963          |
# |    total_timesteps      | 10485760     |
# | train/                  |              |
# |    approx_kl            | 0.0026027537 |
# |    clip_fraction        | 0.00267      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.57        |
# |    explained_variance   | -0.00263     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 440          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000443    |
# |    std                  | 0.874        |
# |    value_loss           | 915          |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.992       |
# |    reward_dist_mean     | 0.189        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 985          |
# |    ep_rew_mean          | -1.55e+03    |
# | time/                   |              |
# |    fps                  | 10876        |
# |    iterations           | 21           |
# |    time_elapsed         | 1012         |
# |    total_timesteps      | 11010048     |
# | train/                  |              |
# |    approx_kl            | 0.0025447821 |
# |    clip_fraction        | 0.00266      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.56        |
# |    explained_variance   | -0.00225     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 464          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000417    |
# |    std                  | 0.871        |
# |    value_loss           | 956          |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.947       |
# |    reward_dist_mean     | 1.56         |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -1.65e+03    |
# | time/                   |              |
# |    fps                  | 10870        |
# |    iterations           | 22           |
# |    time_elapsed         | 1061         |
# |    total_timesteps      | 11534336     |
# | train/                  |              |
# |    approx_kl            | 0.0016556939 |
# |    clip_fraction        | 0.00115      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.55        |
# |    explained_variance   | -0.00192     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 475          |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000348    |
# |    std                  | 0.866        |
# |    value_loss           | 981          |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.945       |
# |    reward_dist_mean     | 1.24         |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -1.58e+03    |
# | time/                   |              |
# |    fps                  | 10861        |
# |    iterations           | 23           |
# |    time_elapsed         | 1110         |
# |    total_timesteps      | 12058624     |
# | train/                  |              |
# |    approx_kl            | 0.0027414495 |
# |    clip_fraction        | 0.00327      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.54        |
# |    explained_variance   | -0.00163     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 496          |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00048     |
# |    std                  | 0.862        |
# |    value_loss           | 1.02e+03     |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.948       |
# |    reward_dist_mean     | 1.31         |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -1.6e+03     |
# | time/                   |              |
# |    fps                  | 10855        |
# |    iterations           | 24           |
# |    time_elapsed         | 1159         |
# |    total_timesteps      | 12582912     |
# | train/                  |              |
# |    approx_kl            | 0.0015627999 |
# |    clip_fraction        | 0.00106      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.53        |
# |    explained_variance   | -0.00135     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 496          |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000331    |
# |    std                  | 0.856        |
# |    value_loss           | 1.02e+03     |
# ------------------------------------------
# -----------------------------------------
# | parking/                |             |
# |    reward_bearing_mean  | -0.958      |
# |    reward_dist_mean     | 1.34        |
# |    reward_goal_mean     | 0           |
# |    reward_time_mean     | -0.5        |
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -1.68e+03   |
# | time/                   |             |
# |    fps                  | 10849       |
# |    iterations           | 25          |
# |    time_elapsed         | 1208        |
# |    total_timesteps      | 13107200    |
# | train/                  |             |
# |    approx_kl            | 0.002089792 |
# |    clip_fraction        | 0.00186     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.51       |
# |    explained_variance   | -0.00126    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 495         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.000245   |
# |    std                  | 0.852       |
# |    value_loss           | 1.02e+03    |
# -----------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.956       |
# |    reward_dist_mean     | 1.18         |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 991          |
# |    ep_rew_mean          | -1.6e+03     |
# | time/                   |              |
# |    fps                  | 10845        |
# |    iterations           | 26           |
# |    time_elapsed         | 1256         |
# |    total_timesteps      | 13631488     |
# | train/                  |              |
# |    approx_kl            | 0.0018315532 |
# |    clip_fraction        | 0.00418      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.51        |
# |    explained_variance   | -0.00105     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 499          |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000237    |
# |    std                  | 0.85         |
# |    value_loss           | 1.03e+03     |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.965       |
# |    reward_dist_mean     | 0.917        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 992          |
# |    ep_rew_mean          | -1.62e+03    |
# | time/                   |              |
# |    fps                  | 10838        |
# |    iterations           | 27           |
# |    time_elapsed         | 1306         |
# |    total_timesteps      | 14155776     |
# | train/                  |              |
# |    approx_kl            | 0.0017171359 |
# |    clip_fraction        | 0.00127      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.5         |
# |    explained_variance   | -0.000948    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 500          |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000212    |
# |    std                  | 0.845        |
# |    value_loss           | 1.03e+03     |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.962       |
# |    reward_dist_mean     | 0.885        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 965          |
# |    ep_rew_mean          | -1.55e+03    |
# | time/                   |              |
# |    fps                  | 10834        |
# |    iterations           | 28           |
# |    time_elapsed         | 1354         |
# |    total_timesteps      | 14680064     |
# | train/                  |              |
# |    approx_kl            | 0.0014043915 |
# |    clip_fraction        | 0.000835     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.49        |
# |    explained_variance   | -0.000846    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 487          |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00028     |
# |    std                  | 0.84         |
# |    value_loss           | 1e+03        |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.973       |
# |    reward_dist_mean     | 0.544        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 963          |
# |    ep_rew_mean          | -1.52e+03    |
# | time/                   |              |
# |    fps                  | 10830        |
# |    iterations           | 29           |
# |    time_elapsed         | 1403         |
# |    total_timesteps      | 15204352     |
# | train/                  |              |
# |    approx_kl            | 0.0016384545 |
# |    clip_fraction        | 0.00134      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.48        |
# |    explained_variance   | -0.000762    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 495          |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000298    |
# |    std                  | 0.835        |
# |    value_loss           | 1.01e+03     |
# ------------------------------------------
# Eval num_timesteps=15360000, episode_reward=-1349.41 +/- 603.50
# Episode length: 1001.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | -1.35e+03    |
# | parking/                |              |
# |    reward_bearing_mean  | -0.979       |
# |    reward_dist_mean     | 0.43         |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | time/                   |              |
# |    total_timesteps      | 15360000     |
# | train/                  |              |
# |    approx_kl            | 0.0021271298 |
# |    clip_fraction        | 0.00255      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.47        |
# |    explained_variance   | -0.00069     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 506          |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000286    |
# |    std                  | 0.832        |
# |    value_loss           | 1.04e+03     |
# ------------------------------------------
# New best mean reward!
# --------------------------------------
# | parking/               |           |
# |    reward_bearing_mean | -0.967    |
# |    reward_dist_mean    | 0.679     |
# |    reward_goal_mean    | 0         |
# |    reward_time_mean    | -0.5      |
# | rollout/               |           |
# |    ep_len_mean         | 954       |
# |    ep_rew_mean         | -1.57e+03 |
# | time/                  |           |
# |    fps                 | 10786     |
# |    iterations          | 30        |
# |    time_elapsed        | 1458      |
# |    total_timesteps     | 15728640  |
# --------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.967       |
# |    reward_dist_mean     | 0.657        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 973          |
# |    ep_rew_mean          | -1.5e+03     |
# | time/                   |              |
# |    fps                  | 10781        |
# |    iterations           | 31           |
# |    time_elapsed         | 1507         |
# |    total_timesteps      | 16252928     |
# | train/                  |              |
# |    approx_kl            | 0.0016695706 |
# |    clip_fraction        | 0.00133      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.46        |
# |    explained_variance   | -0.000636    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 506          |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000202    |
# |    std                  | 0.827        |
# |    value_loss           | 1.04e+03     |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.967       |
# |    reward_dist_mean     | 0.635        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 963          |
# |    ep_rew_mean          | -1.54e+03    |
# | time/                   |              |
# |    fps                  | 10777        |
# |    iterations           | 32           |
# |    time_elapsed         | 1556         |
# |    total_timesteps      | 16777216     |
# | train/                  |              |
# |    approx_kl            | 0.0025478746 |
# |    clip_fraction        | 0.00441      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.45        |
# |    explained_variance   | -0.000575    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 521          |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000293    |
# |    std                  | 0.826        |
# |    value_loss           | 1.07e+03     |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.97        |
# |    reward_dist_mean     | 0.594        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 897          |
# |    ep_rew_mean          | -1.38e+03    |
# | time/                   |              |
# |    fps                  | 10772        |
# |    iterations           | 33           |
# |    time_elapsed         | 1606         |
# |    total_timesteps      | 17301504     |
# | train/                  |              |
# |    approx_kl            | 0.0017143196 |
# |    clip_fraction        | 0.00225      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.45        |
# |    explained_variance   | -0.000531    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 503          |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000285    |
# |    std                  | 0.822        |
# |    value_loss           | 1.04e+03     |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.956       |
# |    reward_dist_mean     | 0.765        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 933          |
# |    ep_rew_mean          | -1.49e+03    |
# | time/                   |              |
# |    fps                  | 10767        |
# |    iterations           | 34           |
# |    time_elapsed         | 1655         |
# |    total_timesteps      | 17825792     |
# | train/                  |              |
# |    approx_kl            | 0.0019726641 |
# |    clip_fraction        | 0.00161      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.44        |
# |    explained_variance   | -0.000462    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 515          |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000184    |
# |    std                  | 0.82         |
# |    value_loss           | 1.05e+03     |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.961       |
# |    reward_dist_mean     | 0.607        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 938          |
# |    ep_rew_mean          | -1.46e+03    |
# | time/                   |              |
# |    fps                  | 10761        |
# |    iterations           | 35           |
# |    time_elapsed         | 1705         |
# |    total_timesteps      | 18350080     |
# | train/                  |              |
# |    approx_kl            | 0.0014469912 |
# |    clip_fraction        | 0.00106      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.43        |
# |    explained_variance   | -0.000402    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 524          |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000193    |
# |    std                  | 0.819        |
# |    value_loss           | 1.07e+03     |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.954       |
# |    reward_dist_mean     | 0.697        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 869          |
# |    ep_rew_mean          | -1.3e+03     |
# | time/                   |              |
# |    fps                  | 10756        |
# |    iterations           | 36           |
# |    time_elapsed         | 1754         |
# |    total_timesteps      | 18874368     |
# | train/                  |              |
# |    approx_kl            | 0.0016458784 |
# |    clip_fraction        | 0.000931     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.43        |
# |    explained_variance   | -0.000345    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 521          |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000189    |
# |    std                  | 0.818        |
# |    value_loss           | 1.07e+03     |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.964       |
# |    reward_dist_mean     | 0.618        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 885          |
# |    ep_rew_mean          | -1.3e+03     |
# | time/                   |              |
# |    fps                  | 10752        |
# |    iterations           | 37           |
# |    time_elapsed         | 1804         |
# |    total_timesteps      | 19398656     |
# | train/                  |              |
# |    approx_kl            | 0.0013836311 |
# |    clip_fraction        | 0.00191      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.42        |
# |    explained_variance   | -0.000317    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 509          |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000292    |
# |    std                  | 0.814        |
# |    value_loss           | 1.04e+03     |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.961       |
# |    reward_dist_mean     | 0.577        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 895          |
# |    ep_rew_mean          | -1.38e+03    |
# | time/                   |              |
# |    fps                  | 10748        |
# |    iterations           | 38           |
# |    time_elapsed         | 1853         |
# |    total_timesteps      | 19922944     |
# | train/                  |              |
# |    approx_kl            | 0.0016886769 |
# |    clip_fraction        | 0.00296      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.41        |
# |    explained_variance   | -0.000302    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 519          |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000278    |
# |    std                  | 0.808        |
# |    value_loss           | 1.06e+03     |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.956       |
# |    reward_dist_mean     | 0.493        |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 932          |
# |    ep_rew_mean          | -1.43e+03    |
# | time/                   |              |
# |    fps                  | 10744        |
# |    iterations           | 39           |
# |    time_elapsed         | 1903         |
# |    total_timesteps      | 20447232     |
# | train/                  |              |
# |    approx_kl            | 0.0015449467 |
# |    clip_fraction        | 0.00215      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.4         |
# |    explained_variance   | -0.00026     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 516          |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000333    |
# |    std                  | 0.804        |
# |    value_loss           | 1.05e+03     |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.944       |
# |    reward_dist_mean     | 0.687        |
# |    reward_goal_mean     | 0.391        |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 940          |
# |    ep_rew_mean          | -1.49e+03    |
# | time/                   |              |
# |    fps                  | 10739        |
# |    iterations           | 40           |
# |    time_elapsed         | 1952         |
# |    total_timesteps      | 20971520     |
# | train/                  |              |
# |    approx_kl            | 0.0022662717 |
# |    clip_fraction        | 0.00244      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.39        |
# |    explained_variance   | -0.00025     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 526          |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000169    |
# ...
# |    explained_variance   | 0.0143       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 843          |
# |    n_updates            | 1770         |
# |    policy_gradient_loss | -0.000309    |
# |    std                  | 0.521        |
# |    value_loss           | 1.68e+03     |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.846       |
# |    reward_dist_mean     | 1.14         |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 530          |
# |    ep_rew_mean          | -398         |
# | time/                   |              |
# |    fps                  | 10355        |
# |    iterations           | 179          |
# |    time_elapsed         | 9062         |
# |    total_timesteps      | 93847552     |
# | train/                  |              |
# |    approx_kl            | 0.0017739325 |
# |    clip_fraction        | 0.0049       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 0.0132       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 878          |
# |    n_updates            | 1780         |
# |    policy_gradient_loss | -0.000307    |
# |    std                  | 0.52         |
# |    value_loss           | 1.74e+03     |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.808       |
# |    reward_dist_mean     | 1.24         |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 513          |
# |    ep_rew_mean          | -406         |
# | time/                   |              |
# |    fps                  | 10357        |
# |    iterations           | 180          |
# |    time_elapsed         | 9111         |
# |    total_timesteps      | 94371840     |
# | train/                  |              |
# |    approx_kl            | 0.0017078787 |
# |    clip_fraction        | 0.00357      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0.0134       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 850          |
# |    n_updates            | 1790         |
# |    policy_gradient_loss | -0.000218    |
# |    std                  | 0.518        |
# |    value_loss           | 1.69e+03     |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.814       |
# |    reward_dist_mean     | 1.13         |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 438          |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 10359        |
# |    iterations           | 181          |
# |    time_elapsed         | 9160         |
# |    total_timesteps      | 94896128     |
# | train/                  |              |
# |    approx_kl            | 0.0012713757 |
# |    clip_fraction        | 0.00318      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.012        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 830          |
# |    n_updates            | 1800         |
# |    policy_gradient_loss | -0.000235    |
# |    std                  | 0.513        |
# |    value_loss           | 1.66e+03     |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.807       |
# |    reward_dist_mean     | 1.57         |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 529          |
# |    ep_rew_mean          | -423         |
# | time/                   |              |
# |    fps                  | 10361        |
# |    iterations           | 182          |
# |    time_elapsed         | 9208         |
# |    total_timesteps      | 95420416     |
# | train/                  |              |
# |    approx_kl            | 0.0011815957 |
# |    clip_fraction        | 0.00302      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.0136       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 834          |
# |    n_updates            | 1810         |
# |    policy_gradient_loss | -0.000211    |
# |    std                  | 0.51         |
# |    value_loss           | 1.66e+03     |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.839       |
# |    reward_dist_mean     | 1.15         |
# |    reward_goal_mean     | 0.391        |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 511          |
# |    ep_rew_mean          | -412         |
# | time/                   |              |
# |    fps                  | 10363        |
# |    iterations           | 183          |
# |    time_elapsed         | 9257         |
# |    total_timesteps      | 95944704     |
# | train/                  |              |
# |    approx_kl            | 0.0017871908 |
# |    clip_fraction        | 0.00317      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.0119       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 865          |
# |    n_updates            | 1820         |
# |    policy_gradient_loss | -0.000174    |
# |    std                  | 0.509        |
# |    value_loss           | 1.74e+03     |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.803       |
# |    reward_dist_mean     | 1.49         |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 523          |
# |    ep_rew_mean          | -387         |
# | time/                   |              |
# |    fps                  | 10365        |
# |    iterations           | 184          |
# |    time_elapsed         | 9306         |
# |    total_timesteps      | 96468992     |
# | train/                  |              |
# |    approx_kl            | 0.0015502183 |
# |    clip_fraction        | 0.00506      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.0145       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 854          |
# |    n_updates            | 1830         |
# |    policy_gradient_loss | -0.000284    |
# |    std                  | 0.509        |
# |    value_loss           | 1.7e+03      |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.808       |
# |    reward_dist_mean     | 1.1          |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 495          |
# |    ep_rew_mean          | -244         |
# | time/                   |              |
# |    fps                  | 10367        |
# |    iterations           | 185          |
# |    time_elapsed         | 9355         |
# |    total_timesteps      | 96993280     |
# | train/                  |              |
# |    approx_kl            | 0.0016089632 |
# |    clip_fraction        | 0.0041       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.0148       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 827          |
# |    n_updates            | 1840         |
# |    policy_gradient_loss | -0.000203    |
# |    std                  | 0.508        |
# |    value_loss           | 1.65e+03     |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.806       |
# |    reward_dist_mean     | 1.38         |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 477          |
# |    ep_rew_mean          | -307         |
# | time/                   |              |
# |    fps                  | 10369        |
# |    iterations           | 186          |
# |    time_elapsed         | 9404         |
# |    total_timesteps      | 97517568     |
# | train/                  |              |
# |    approx_kl            | 0.0017360104 |
# |    clip_fraction        | 0.00331      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.013        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 874          |
# |    n_updates            | 1850         |
# |    policy_gradient_loss | -0.00014     |
# |    std                  | 0.507        |
# |    value_loss           | 1.75e+03     |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.785       |
# |    reward_dist_mean     | 1.45         |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 474          |
# |    ep_rew_mean          | -234         |
# | time/                   |              |
# |    fps                  | 10371        |
# |    iterations           | 187          |
# |    time_elapsed         | 9452         |
# |    total_timesteps      | 98041856     |
# | train/                  |              |
# |    approx_kl            | 0.0014493098 |
# |    clip_fraction        | 0.00377      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.0125       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 858          |
# |    n_updates            | 1860         |
# |    policy_gradient_loss | -0.000199    |
# |    std                  | 0.504        |
# |    value_loss           | 1.7e+03      |
# ------------------------------------------
# -----------------------------------------
# | parking/                |             |
# |    reward_bearing_mean  | -0.788      |
# |    reward_dist_mean     | 1.74        |
# |    reward_goal_mean     | 0           |
# |    reward_time_mean     | -0.5        |
# | rollout/                |             |
# |    ep_len_mean          | 506         |
# |    ep_rew_mean          | -296        |
# | time/                   |             |
# |    fps                  | 10373       |
# |    iterations           | 188         |
# |    time_elapsed         | 9501        |
# |    total_timesteps      | 98566144    |
# | train/                  |             |
# |    approx_kl            | 0.001711954 |
# |    clip_fraction        | 0.00294     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.0134      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 878         |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.000258   |
# |    std                  | 0.502       |
# |    value_loss           | 1.76e+03    |
# -----------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.824       |
# |    reward_dist_mean     | 1.23         |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 448          |
# |    ep_rew_mean          | -213         |
# | time/                   |              |
# |    fps                  | 10375        |
# |    iterations           | 189          |
# |    time_elapsed         | 9550         |
# |    total_timesteps      | 99090432     |
# | train/                  |              |
# |    approx_kl            | 0.0014284278 |
# |    clip_fraction        | 0.00266      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0129       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 868          |
# |    n_updates            | 1880         |
# |    policy_gradient_loss | -0.000164    |
# |    std                  | 0.501        |
# |    value_loss           | 1.74e+03     |
# ------------------------------------------
# ------------------------------------------
# | parking/                |              |
# |    reward_bearing_mean  | -0.842       |
# |    reward_dist_mean     | 1.31         |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | rollout/                |              |
# |    ep_len_mean          | 516          |
# |    ep_rew_mean          | -383         |
# | time/                   |              |
# |    fps                  | 10377        |
# |    iterations           | 190          |
# |    time_elapsed         | 9599         |
# |    total_timesteps      | 99614720     |
# | train/                  |              |
# |    approx_kl            | 0.0019827199 |
# |    clip_fraction        | 0.00525      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0123       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 864          |
# |    n_updates            | 1890         |
# |    policy_gradient_loss | -0.000225    |
# |    std                  | 0.5          |
# |    value_loss           | 1.72e+03     |
# ------------------------------------------
# Eval num_timesteps=99840000, episode_reward=16.69 +/- 925.27
# Episode length: 450.00 +/- 280.63
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 450          |
# |    mean_reward          | 16.7         |
# | parking/                |              |
# |    reward_bearing_mean  | -0.804       |
# |    reward_dist_mean     | 1.31         |
# |    reward_goal_mean     | 0            |
# |    reward_time_mean     | -0.5         |
# | time/                   |              |
# |    total_timesteps      | 99840000     |
# | train/                  |              |
# |    approx_kl            | 0.0017594825 |
# |    clip_fraction        | 0.00373      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.0125       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 837          |
# |    n_updates            | 1900         |
# |    policy_gradient_loss | -0.000228    |
# |    std                  | 0.497        |
# |    value_loss           | 1.67e+03     |
# ------------------------------------------
# --------------------------------------
# | parking/               |           |
# |    reward_bearing_mean | -0.812    |
# |    reward_dist_mean    | 1.3       |
# |    reward_goal_mean    | 0.391     |
# |    reward_time_mean    | -0.5      |
# | rollout/               |           |
# |    ep_len_mean         | 476       |
# |    ep_rew_mean         | -241      |
# | time/                  |           |
# |    fps                 | 10376     |
# |    iterations          | 191       |
# |    time_elapsed        | 9650      |
# |    total_timesteps     | 100139008 |
# --------------------------------------

# %%
model.save("parking-task/best_model/best_model.zip")

# %%
robot = Robot()
np.random.seed(np.random.randint(10))
envs = gym.make("gymnasium_env/ParkingTask-v0")
envs = gym.wrappers.RecordEpisodeStatistics(envs)
envs.unwrapped.robot.max_speed = (1.5, 0.5)
obs, info = envs.reset()


done = False
pos_traj = [envs.unwrapped.start_config[:2].copy()]
orientation_traj = [envs.unwrapped.start_config[2]]
bearing_traj = [envs.unwrapped.bearing.copy()]

rewards_episode = []
rewards_dist = []
rewards_bearing = []  
rewards_orient = []
rewards_goal = []

total_reward = 0
rewards_evolution = []

model = PPO.load("parking-task/best_model/best_model.zip", env=envs)


while not done:
  action, _ = model.predict(obs, deterministic=True)
  print(f"action: {action} obs: {obs}")
  next_obs, rew, terminated, truncated, info = envs.step(action)
  total_reward += rew
  pos_traj.append(envs.unwrapped.robot.config[:2].copy())
  orientation_traj.append(envs.unwrapped.robot.config[2].copy())
  bearing_traj.append(envs.unwrapped.bearing.copy())

  done = terminated or truncated
  rewards_episode.append(rew)
  rewards_evolution.append(total_reward)
  rewards_dist.append(envs.unwrapped.reward_dist)
  rewards_bearing.append(envs.unwrapped.reward_bearing)
  rewards_orient.append(envs.unwrapped.reward_orient)
  rewards_goal.append(envs.unwrapped.reward_goal)

  obs = next_obs.copy()

print(f"truncate: {truncated} terminate: {terminated} outbound: {envs.unwrapped.timeout} pos: {envs.unwrapped.robot.config}")
print(f"distance to target: {envs.unwrapped.distance_to_target}")
print(f"final time: {envs.unwrapped.time}")
print(f"episode_returns: {envs.episode_returns}")
print(f"episode_length: {envs.episode_lengths}")
import matplotlib.pyplot as plt

def plot_traj():


    plt.figure()
    x, y = zip(*pos_traj)
    plt.plot(x, y, label="pos")
    plt.scatter(envs.unwrapped.target_config[0], envs.unwrapped.target_config[1], c="r", label="goal")
    plt.scatter(envs.unwrapped.start_config[0], envs.unwrapped.start_config[1], c="g", label="start")
    plt.scatter(envs.unwrapped.robot.config[0], envs.unwrapped.robot.config[1], c="b", label="final")

    dx_target, dy_target = np.cos(envs.unwrapped.target_config[2]), np.sin(envs.unwrapped.target_config[2])
    dx_start, dy_start = np.cos(envs.unwrapped.start_config[2]), np.sin(envs.unwrapped.start_config[2])
    dx_final, dy_final = np.cos(envs.unwrapped.robot.config[2]), np.sin(envs.unwrapped.robot.config[2])
    
    length = 1.5
    width = 0.3

    plt.arrow(x=envs.unwrapped.target_config[0], y=envs.unwrapped.target_config[1],
              dx=length*dx_target, dy=length*dy_target, color="r", head_width=0.3)
    plt.arrow(x=envs.unwrapped.start_config[0], y=envs.unwrapped.start_config[1],
              dx=length*dx_start, dy=length*dy_start, color="g", head_width=0.3)
    plt.arrow(x=envs.unwrapped.robot.config[0], y=envs.unwrapped.robot.config[1],
              dx=0.6*length*dx_final, dy=0.6*length*dy_final, color="b", head_width=0.1)


    plt.legend()
    plt.axis("equal")

    plt.figure()
    plt.plot(orientation_traj, label="head")
    plt.hlines(envs.unwrapped.target_config[2:], xmin=0, xmax=len(orientation_traj), colors=["r"], label="target")
    plt.hlines(envs.unwrapped.start_config[2:], xmin=0, xmax=len(orientation_traj), colors=["g"], label="start")
    plt.legend()

plot_traj()

plt.figure()
plt.plot(rewards_episode, label="reward")
plt.legend()

plt.figure()
plt.plot(rewards_evolution, label="reward evolution")
plt.legend()

plt.figure()
plt.plot(bearing_traj, label="bearing")
plt.legend()

plt.figure()
plt.plot(bearing_traj[1:], rewards_episode, label="bearing vs reward")
plt.legend()

plt.figure()
plt.plot(rewards_dist, label="reward dist")
plt.legend()

plt.figure()
plt.plot(rewards_bearing, label="reward bearing")
plt.legend()  

plt.figure()
plt.plot(rewards_goal, label="reward goal")
plt.legend()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#  -0.08977237 -0.15362053]
# action: [-0.18719718  1.        ] obs: [ 0.07201612 -0.99740347  0.99973743  0.02291447  0.34272445  1.
#   0.21114817  0.35316637]
# action: [0.37555218 1.        ] obs: [ 0.0811569  -0.99670134  0.99975615  0.02208241  0.34281089 -1.
#  -0.09444911 -0.16162348]
# action: [-0.21885055  1.        ] obs: [ 0.06280723 -0.99802568  0.99990634  0.01368612  0.34272963  1.
#   0.19271533  0.3223356 ]
# action: [-0.17831144  1.        ] obs: [ 0.07350238 -0.99729504  0.99940815  0.0343999   0.34279963  1.
#  -0.11041961 -0.18895257]
# action: [0.41164264 1.        ] obs: [ 0.08220288 -0.99661562  0.99945113  0.03312763  0.34291569 -1.
#  -0.08842188 -0.1548436 ]
# action: [-0.1871407  1.       ] obs: [ 0.06209759 -0.99807008  0.99973607  0.0229735   0.34275633  1.
#   0.2076916   0.35540662]
# action: [0.37570235 1.        ] obs: [ 0.07124127 -0.99745911  0.99975493  0.02213782  0.34284292 -1.
#  -0.09280017 -0.16251083]
# action: [-0.21886864  1.        ] obs: [ 0.05287371 -0.99860121  0.99990566  0.0137359   0.34276129  1.
#   0.18955816  0.32437627]
# action: [-0.17870085  1.        ] obs: [ 0.06357549 -0.99797703  0.99940644  0.03444953  0.34283148  1.
#  -0.10853357 -0.19006301]
# action: [0.41182286 1.        ] obs: [ 0.07230049 -0.9973829   0.99944888  0.03319548  0.34294797 -1.
#  -0.08705876 -0.15606014]
# action: [-0.18709025  1.        ] obs: [ 0.05217484 -0.99863797  0.99973467  0.02303446  0.34278809  1.
#   0.20421657  0.35762223]
# action: [0.37586242 1.        ] obs: [ 0.06132081 -0.99811811  0.99975365  0.02219544  0.34287485 -1.
#  -0.09114587 -0.16338663]
# action: [-0.21889359  1.        ] obs: [ 0.04293669 -0.9990778   0.99990495  0.01378741  0.34279284  1.
#   0.18638435  0.3263946 ]
# action: [-0.17909583  1.        ] obs: [ 0.05364437 -0.9985601   0.99940466  0.03450124  0.34286322  1.
#  -0.10663969 -0.19116061]
# action: [0.4120133 1.       ] obs: [ 0.0623933  -0.99805164  0.99944654  0.03326567  0.34298016 -1.
#  -0.0856828  -0.15726976]
# action: [-0.18704605  1.        ] obs: [ 0.04224877 -0.99910712  0.99973322  0.02309726  0.34281974  1.
#   0.20072297  0.35981279]
# action: [0.37603226 1.        ] obs: [ 0.05139643 -0.99867833  0.99975232  0.02225521  0.34290667 -1.
#  -0.08948633 -0.16425109]
# truncate: True terminate: False outbound: (True, False) pos: [1.02183615 1.85147272 1.07194324]
# distance to target: 0.6124456020009127
# final time: 20.019999999999662
# episode_returns: -2234.062360636636
# episode_length: 1001

# %%
import matplotlib.pyplot as plt
x = np.linspace(-np.pi, np.pi, 20)
y = np.exp(-4 * np.abs(x)) - 1
plt.figure()
plt.plot(x, y)
x = np.linspace(0, 1, 20)
y = 1-np.exp(-4 * np.abs(x))
plt.figure()
plt.plot(x, y)

# %%
a = [*(3, 2)]
a
# Out:
# [3, 2]
